# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanunivasmanapaka/internship_tasks/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/Bank Customer Churn Prediction.csv')
data
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
data.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %% [markdown]
# used to display the first few rows

# %%
data.tail()
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9995                2            1              0          96270.64      0
# 9996                1            1              1         101699.77      0
# 9997                1            0              1          42085.58      1
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %% [markdown]
#  used to display the last few rows

# %%
data.shape
# Out:
# (10000, 12)

# %% [markdown]
# no of columns and rows

# %%
data.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %% [markdown]
# used to access the column names

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# summary of the given data, providing information about the data types, non-null values, and memory usage.

# %%
data.nunique()
# Out:
# customer_id         10000
# credit_score          460
# country                 3
# gender                  2
# age                    70
# tenure                 11
# balance              6382
# products_number         4
# credit_card             2
# active_member           2
# estimated_salary     9999
# churn                   2
# dtype: int64

# %% [markdown]
# used to count the number of unique values in each column

# %%
data.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %% [markdown]
#  used to count the number of missing values in each column

# %%
data.select_dtypes(include= 'object').head()
# Out:
#   country  gender
# 0  France  Female
# 1   Spain  Female
# 2  France  Female
# 3  France  Female
# 4   Spain  Female

# %% [markdown]
# the data type object typically represents columns that contain string or mixed types of data.

# %%
data.describe()
# Out:
#         customer_id  credit_score           age        tenure        balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        products_number  credit_card  active_member  estimated_salary  \
# count     10000.000000  10000.00000   10000.000000      10000.000000
# mean          1.530200      0.70550       0.515100     100090.239881
# ...

# %% [markdown]
# used to generate descriptive statistics of a data numerical columns

# %%
# Histogram for numerical variables
data['credit_score'].hist(bins=20)
plt.title('Histogram of Numerical Column')
plt.xlabel('Numerical Column')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The resulting plot is a histogram that visualizes the distribution of 'credit_score' values in the dataset. Each bar in the histogram represents the frequency of values falling within a specific range  of credit scores

# %%
# Countplot for categorical variables
sns.countplot(x='country', data=data)
plt.title('Countplot of Categorical Column')
plt.xlabel('country')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# displays the count of observations

# %%
# Scatter plot for numerical variables
sns.scatterplot(x='age', y='credit_score', data=data)
plt.title('Scatter Plot of Numerical Columns')
plt.xlabel('age')
plt.ylabel('credit_score')
plt.show()

# %% [markdown]
# It is a type of data visualization that displays individual data points on a two-dimensional graph.

# %%
# Box plot for numerical and categorical variables
sns.boxplot(x='country', y='age', data=data)
plt.title('Box Plot of Numerical Column by Categorical Column')
plt.xlabel('country')
plt.ylabel('age')
plt.show()

# %%
# Correlation matrix
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
#Box plot for outlier detection
sns.boxplot(x=data['credit_score'])
plt.title('Box Plot for Outlier Detection')
plt.xlabel('Numerical Column')
plt.show()
